# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Get the directory where the current notebook is located
current_dir = Path.cwd()

# Define the path relative to the notebook
data_path = current_dir.parent / "data" / "epidemiology.csv"

# %%
# Load the dataset
data=pd.read_csv(data_path)
data.head(5)
# Out:
#           date location_key  new_confirmed  new_deceased  new_recovered  \
# 0   2020-01-01           AD            0.0           0.0            NaN
# 1   2020-01-02           AD            0.0           0.0            NaN
# 2   2020-01-03           AD            0.0           0.0            NaN
# 3   2020-01-04           AD            0.0           0.0            NaN
# 4   2020-01-05           AD            0.0           0.0            NaN
# ..         ...          ...            ...           ...            ...
# 75  2020-03-16           AD           25.0           0.0            NaN
# 76  2020-03-17           AD            0.0           0.0            NaN
# 77  2020-03-18           AD           36.0           0.0            NaN
# 78  2020-03-19           AD           19.0           0.0            NaN
# 79  2020-03-20           AD           39.0           1.0            NaN
#
#     new_tested  cumulative_confirmed  cumulative_deceased  \
# ...

# %%
# Get unique values from the first column (column index 0)
unique_first_cells = data["location_key"].dropna().unique()
print(unique_first_cells)
# Out:
# <StringArray>
# [        'AD',         'AE',         'AF',     'AF_BAL',     'AF_BAM',
#      'AF_BDG',     'AF_BDS',     'AF_BGL',     'AF_DAY',     'AF_FRA',
#  ...
#  'ZA_NW_DC40',      'ZA_WC',  'ZA_WC_CPT',  'ZA_WC_DC1',  'ZA_WC_DC2',
#   'ZA_WC_DC3',  'ZA_WC_DC4',  'ZA_WC_DC5',         'ZM',         'ZW']
# Length: 20905, dtype: str

# %%
# Return unique location keys
def get_unique_location_keys(data):
    return list(set(data["location_key"].dropna().str.split("_").str[0]))

unique_Country_Keys = get_unique_location_keys(data)

print(unique_Country_Keys)
print(len(unique_Country_Keys))
# Out:
# ['AD', 'PY', 'ZA', 'CL', 'LC', 'NZ', 'VG', 'AW', 'ID', 'GN', 'BI', 'GI', 'IS', 'HN', 'GW', 'MR', 'RU', 'MP', 'GU', 'IN', 'TH', 'OM', 'AI', 'CN', 'CV', 'EH', 'SI', 'VE', 'NL', 'FI', 'MW', 'ZW', 'AR', 'EE', 'IT', 'GB', 'KE', 'RW', 'RE', 'MZ', 'GH', 'DK', 'CH', 'IR', 'PF', 'TT', 'CF', 'ML', 'BW', 'GY', 'IM', 'MU', 'UZ', 'SH', 'SD', 'SO', 'AG', 'PR', 'LA', 'YT', 'KW', 'KP', 'CI', 'JM', 'LV', 'SC', 'MH', 'AF', 'LR', 'MX', 'NO', 'KZ', 'BT', 'BS', 'AE', 'LU', 'BJ', 'PA', 'GE', 'NG', 'VC', 'AU', 'BA', 'UY', 'CW', 'MG', 'SR', 'TJ', 'UG', 'US', 'LB', 'CG', 'CD', 'MS', 'MA', 'PH', 'TO', 'XK', 'SZ', 'PS', 'GG', 'FO', 'DJ', 'BE', 'EC', 'GQ', 'RS', 'SA', 'GA', 'CM', 'BZ', 'HU', 'TZ', 'TW', 'YE', 'BR', 'BY', 'TK', 'BH', 'BG', 'SM', 'PK', 'TG', 'VI', 'JO', 'CY', 'MV', 'ME', 'WS', 'KN', 'CU', 'TR', 'GT', 'FJ', 'ER', 'DM', 'EG', 'SL', 'VN', 'ET', 'SX', 'WF', 'PN', 'SE', 'PE', 'QA', 'DE', 'SG', 'GL', 'TD', 'LI', 'KI', 'LY', 'MT', 'AZ', 'GR', 'SB', 'LK', 'ST', 'UA', 'AO', 'GD', 'VU', 'PT', 'VA', 'FR', '
# ...

# %%
focus_data = data[data['location_key'].isin(unique_Country_Keys)]
focus_data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 226892 entries, 0 to 12525824
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   date                  226892 non-null  str
#  1   location_key          226892 non-null  str
#  2   new_confirmed         226799 non-null  float64
#  3   new_deceased          226624 non-null  float64
#  4   new_recovered         15712 non-null   float64
#  5   new_tested            76705 non-null   float64
#  6   cumulative_confirmed  226798 non-null  float64
#  7   cumulative_deceased   226625 non-null  float64
#  8   cumulative_recovered  14759 non-null   float64
#  9   cumulative_tested     80010 non-null   float64
# dtypes: float64(8), str(2)
# memory usage: 19.0 MB

# %%
focus_data['location_key'].value_counts()
# Out:
# location_key
# AU    990
# TH    990
# AT    989
# BE    989
# BR    989
#      ...
# ZW    987
# TW    974
# HK    693
# MO    152
# EH      1
# Name: count, Length: 232, dtype: int64

# %%
def get_unique_location_keys(data):
    return list(set(data["location_key"].dropna().str.split("_").str[0]))

# Get country codes
unique_Country_Keys = get_unique_location_keys(data)

# Keep ONLY rows where location_key is exactly a country code
focus_data = data[data["location_key"].isin(unique_Country_Keys)]

print(focus_data.info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 226892 entries, 0 to 12525824
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   date                  226892 non-null  str
#  1   location_key          226892 non-null  str
#  2   new_confirmed         226799 non-null  float64
#  3   new_deceased          226624 non-null  float64
#  4   new_recovered         15712 non-null   float64
#  5   new_tested            76705 non-null   float64
#  6   cumulative_confirmed  226798 non-null  float64
#  7   cumulative_deceased   226625 non-null  float64
#  8   cumulative_recovered  14759 non-null   float64
#  9   cumulative_tested     80010 non-null   float64
# dtypes: float64(8), str(2)
# memory usage: 19.0 MB
# None

# %%
focus_data
# Out:
#                 date location_key  new_confirmed  new_deceased  new_recovered  \
# 0         2020-01-01           AD            0.0           0.0            NaN
# 1         2020-01-02           AD            0.0           0.0            NaN
# 2         2020-01-03           AD            0.0           0.0            NaN
# 3         2020-01-04           AD            0.0           0.0            NaN
# 4         2020-01-05           AD            0.0           0.0            NaN
# ...              ...          ...            ...           ...            ...
# 12525820  2022-09-09           ZW           11.0           0.0            NaN
# 12525821  2022-09-10           ZW           18.0           0.0            NaN
# 12525822  2022-09-11           ZW            0.0           0.0            NaN
# 12525823  2022-09-12           ZW           51.0           0.0            NaN
# 12525824  2022-09-13           ZW            0.0           0.0            NaN
#
# ...
