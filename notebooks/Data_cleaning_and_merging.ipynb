# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Get the directory where the current notebook is located
current_dir = Path.cwd()

# Define the path relative to the notebook
data_path = current_dir.parent / "data" / "epidemiology.csv"

# %%
# Load the dataset
data=pd.read_csv(data_path)
data.head(2)
# Out:
#          date location_key  new_confirmed  new_deceased  new_recovered  \
# 0  2020-01-01           AD            0.0           0.0            NaN
# 1  2020-01-02           AD            0.0           0.0            NaN
#
#    new_tested  cumulative_confirmed  cumulative_deceased  \
# 0         NaN                   0.0                  0.0
# 1         NaN                   0.0                  0.0
#
#    cumulative_recovered  cumulative_tested
# 0                   NaN                NaN
# 1                   NaN                NaN

# %%
# Get unique values from the first column (column index 0)
unique_first_cells = data[1].dropna().unique()
print(unique_first_cells)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:578, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Get unique values from the first column (column index 0)
# ...

# %%
# Convert to list if needed
unique_Location_Keys = unique_first_cells.tolist()
# Return unique location keys
def get_unique_location_keys(data):
    return list(set(data[1].dropna().str.split("_").str[0]))

unique_Country_Keys = get_unique_location_keys(data)
print(unique_Country_Keys)
print(len(unique_Country_Keys))
# Out:
# ['JP', 'ER', 'ZA', 'GG', 'SZ', 'SR', 'EE', 'HN', 'MQ', 'PW', 'AU', 'VG', 'CL', 'MT', 'PY', 'IN', 'RE', 'SO', 'ZW', 'NP', 'GU', 'CO', 'ST', 'BF', 'BM', 'CN', 'HK', 'SI', 'KN', 'HU', 'IQ', 'AI', 'KI', 'MR', 'ME', 'OM', 'TM', 'YT', 'MV', 'EH', 'IR', 'LT', 'JO', 'LV', 'GA', 'AT', 'PN', 'GI', 'VA', 'CU', 'CF', 'PK', 'SA', 'MZ', 'BY', 'AS', 'MG', 'NI', 'SS', 'KP', 'NE', 'VI', 'CI', 'EG', 'GB', 'PL', 'SL', 'BJ', 'GH', 'RW', 'IE', 'GQ', 'CZ', 'PT', 'TL', 'TN', 'TD', 'RO', 'DZ', 'FJ', 'VE', 'HT', 'NL', 'NG', 'FM', 'NZ', 'GW', 'TW', 'BT', 'GY', 'AO', 'DO', 'IL', 'VC', 'CY', 'BN', 'BS', 'DE', 'YE', 'MK', 'PE', 'SE', 'KW', 'PF', 'WS', 'LR', 'LK', 'KG', 'AW', 'LI', 'CK', 'MM', 'JE', 'FO', 'CG', 'SM', 'BW', 'MC', 'NR', 'MX', 'MH', 'SX', 'SG', 'TV', 'CD', 'LY', 'BE', 'SN', 'ZM', 'EC', 'BZ', 'KZ', 'MP', 'RS', 'FK', 'LA', 'WF', 'AZ', 'US', 'TK', 'BH', 'KH', 'BD', 'MW', 'QA', 'BI', 'SD', 'SK', 'MU', 'UG', 'SB', 'MD', 'RU', 'TT', 'UY', 'UZ', 'XK', 'DJ', 'AF', 'VN', 'SH', 'ID', 'TZ', 'PA', 'SY', 'LU', '
# ...

# %%
focus_data = data[data['Location_key'].isin(unique_Country_Keys)]
focus_data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 focus_data
#
# NameError: name 'focus_data' is not defined
