# %% [markdown]
# Gradiant map (plotly/folium) displaying data by month for the world. Menu to choose between displaying:
# - deaths,
# - infections etc. by month.
#
# Anything that seems interesting?
