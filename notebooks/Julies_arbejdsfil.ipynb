# %%
fig = px.choropleth_map(
    sunday_theft_by_district,
    geojson=counties,
    locations='Police District',
    featureidkey="properties.DISTRICT",
    color='Thefts',
    color_continuous_scale="YlOrRd",
    range_color=(0, sunday_theft_by_district['Thefts'].max()),
    map_style="carto-positron",
    zoom=10.5,
    center={"lat": 37.76, "lon": -122.45},
    opacity=0.65,
    title="Motor Vehicle Thefts on Sundays by SF Police District",
    labels={'Thefts': 'Number of thefts'}
)
fig.update_layout(
    margin={"r": 0, "t": 40, "l": 0, "b": 0},
    title_font_size=16,
    coloraxis_colorbar=dict(title="Thefts", tickformat=",d")
)
fig.show()
