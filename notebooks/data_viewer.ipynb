# %%
import pandas as pd
import numpy as np
from pathlib import Path
# Get the directory where the current notebook is located
current_dir = Path.cwd()

# Define the path relative to the notebook
# This works regardless of the operating system
data_path = current_dir.parent / "data" / "epidemiology.csv"

# %%
data = pd.read_csv(data_path)

# %%
data[data['date'] == pd.Timestamp(2021, 12, 1)]
# Out:
#                date location_key  new_confirmed  new_deceased  new_recovered  \
# 700      2021-12-01           AD          232.0           1.0            NaN
# 1687     2021-12-01           AE           64.0           0.0            NaN
# 2674     2021-12-01           AF           28.0           1.0            NaN
# 3336     2021-12-01       AF_BAL            0.0           0.0            7.0
# 3833     2021-12-01       AF_BAM            0.0           0.0            0.0
# ...             ...          ...            ...           ...            ...
# 12522045 2021-12-01    ZA_WC_DC3           18.0           NaN            NaN
# 12522917 2021-12-01    ZA_WC_DC4           22.0           NaN            NaN
# 12523693 2021-12-01    ZA_WC_DC5            3.0           NaN            NaN
# 12524551 2021-12-01           ZM           25.0           0.0            NaN
# 12525538 2021-12-01           ZW         1042.0           0.0            NaN
#
# ...

# %%
data[data['location_key'] == 'AE']
# Out:
#            date location_key  new_confirmed  new_deceased  new_recovered  \
# 987  2020-01-01           AE            0.0           0.0            NaN
# 988  2020-01-02           AE            0.0           0.0            NaN
# 989  2020-01-03           AE            0.0           0.0            NaN
# 990  2020-01-04           AE            0.0           0.0            NaN
# 991  2020-01-05           AE            0.0           0.0            NaN
# ...         ...          ...            ...           ...            ...
# 1969 2022-09-09           AE          412.0           0.0            NaN
# 1970 2022-09-10           AE          400.0           0.0            NaN
# 1971 2022-09-11           AE          387.0           0.0            NaN
# 1972 2022-09-12           AE          377.0           0.0            NaN
# 1973 2022-09-13           AE          402.0           0.0            NaN
#
#       new_tested  cumulative_confirmed  cumulative_deceased  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12525825 entries, 0 to 12525824
# Data columns (total 10 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   date                  datetime64[us]
#  1   location_key          str
#  2   new_confirmed         float64
#  3   new_deceased          float64
#  4   new_recovered         float64
#  5   new_tested            float64
#  6   cumulative_confirmed  float64
#  7   cumulative_deceased   float64
#  8   cumulative_recovered  float64
#  9   cumulative_tested     float64
# dtypes: datetime64[us](1), float64(8), str(1)
# memory usage: 955.6 MB

# %%
keys = data['location_key'].unique()
keys_df = pd.DataFrame(keys, columns=['location_key'])

# %%
keys_df.to_csv("keys.csv", index=False)
